# %%
from datetime import date

from pyxirr import xirr

# %%
from datetime import date

from pyxirr import xirr

dates = [
    date(2024, 9, 14),
    date(2024, 9, 16),
    date(2024, 9, 16),
    date(2025, 12, 2),
    date(2025, 12, 2),
    date(2026, 1, 20),
]
price = [
    14980,
    -30502,
    -1812,
    11432.39964,
    11943.75035,
    -21000
]

# price = [-30502.0, -1812.0, 11432.39964, 11943.750375, -2832.470085144043]

print(xirr(dates, price))
# Out:
# 8.56841668847524e+60

# %%
dates = [date(2020, 1, 1), date(2020, 3, 1), date(2020, 10, 30), date(2021, 2, 15)]
values = [-10000, 5750, 4250, 3250]
xirr(dates, values)
# Out:
# 0.6342972615260243
